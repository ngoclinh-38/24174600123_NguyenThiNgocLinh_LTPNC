# %%
import tkinter as tk
from tkinter import messagebox

# %%
zodiacs = [
    "Tý ", "Sửu ", "Dần ", "Mão ",
    "Thìn ", "Tỵ", "Ngọ 🐴", "Mùi ",
    "Thân ", "Dậu ", "Tuất ", "Hợi "
]

# %% [markdown]
# HÀM XỬ LÝ

# %%
def convert_year():
    global entry_year, result_label
    try:
        year = int(entry_year.get())
        zodiac = zodiacs[(year - 4) % 12]

        messagebox.showinfo(
            "Kết quả",
            f"Năm âm lịch: {zodiac}"
        )

        result_label.config(
            text=f"Năm {year}\nCon giáp: {zodiac}",
            font=("Arial", 18)
        )

    except:
        messagebox.showerror("Lỗi", "Vui lòng nhập năm hợp lệ")

# %% [markdown]
# Tạo giao diện

# %%
root = tk.Tk()
root.title("Chuyển đổi năm âm lịch")
root.geometry("400x300")

tk.Label(root, text="Nhập năm dương lịch:", font=("Arial", 12)).pack(pady=10)

entry_year = tk.Entry(root, font=("Arial", 12))
entry_year.pack()

tk.Button(root, text="Chuyển đổi", command=convert_year).pack(pady=15)

result_label = tk.Label(root, text="", fg="blue")
result_label.pack(pady=20)

# %% [markdown]
# Chạy chương trình

# %%
root.mainloop()
