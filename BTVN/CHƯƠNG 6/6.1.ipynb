# %% [markdown]
# Tạo nhiều luồng(multi-threads) và in tên của các luồng

# %%
import threading

# Hàm mà mỗi luồng sẽ chạy
def in_ten_luong():
    print("Tên luồng đang chạy:", threading.current_thread().name)

# Tạo danh sách luồng
threads = []

for i in range(5):
    t = threading.Thread(target=in_ten_luong, name=f"Luong-{i+1}")
    threads.append(t)
    t.start()

# Chờ tất cả luồng chạy xong
for t in threads:
    t.join()

print("Chương trình kết thúc")
# Out:
# Tên luồng đang chạy: Luong-1
# Tên luồng đang chạy: Luong-2
# Tên luồng đang chạy: Luong-3
# Tên luồng đang chạy: Luong-4
# Tên luồng đang chạy: Luong-5
# Chương trình kết thúc
